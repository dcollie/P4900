# %% [markdown]
# # $\LARGE K-Nearest \ Neighbor$
#
# # Act 1 - Read Data
# #### Import the usual 4  packages!

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1.1 Read your dataset (corrected format, star formation)!
# - print columns
# - print the head(3)!

# %%
cat = pd.read_csv("Data/HiGAL_clump_catalogue_correct_formatting.csv",index_col=False)

# %%
cat.columns
# Out:
# Index(['ID', 'DESIGNATION', 'GLON', 'GLAT', 'ra', 'dec', 'DESIGNATION_70',
#        'F70', 'DF70', 'F70_TOT', 'DF70_TOT', 'F70_ADD', 'DF70_ADD',
#        'F70_ADD_TOT', 'DF70_ADD_TOT', 'ULIM_70', 'DESIGNATION_160', 'F160',
#        'DF160', 'F160_ADD', 'DF160_ADD', 'ULIM_160', 'DESIGNATION_250', 'F250',
#        'DF250', 'DESIGNATION_350', 'F350', 'DF350', 'FSC350', 'DFSC350',
#        'DESIGNATION_500', 'F500', 'DF500', 'FSC500', 'DFSC500',
#        'DESIGNATION_21', 'F21', 'DF21', 'F21_TOT', 'DF21_TOT',
#        'DESIGNATION_22', 'F22', 'DF22', 'F22_TOT', 'DF22_TOT',
#        'DESIGNATION_24', 'F24', 'DF24', 'F24_TOT', 'DF24_TOT',
#        'DESIGNATION_870', 'F870', 'DF870', 'DESIGNATION_1100', 'F1100',
#        'DF1100', 'DFWHM250', 'DIST', 'NEAR_DIST', 'FAR_DIST', 'DIST_FLAG',
#        'DIAM', 'M_LARS', 'FIT_TYPE', 'EVOL_FLAG', 'MASS', 'DMASS', 'TEMP',
#        'DTEMP', 'LAM_0_TK', 'L_BOL', 'LRATIO', 'T_BOL', 'SURF_DENS'],
#       dtype='object')

# %%
# Out:
# Index(['ID', 'DESIGNATION', 'GLON', 'GLAT', 'ra', 'dec', 'DESIGNATION_70',
#        'F70', 'DF70', 'F70_TOT', 'DF70_TOT', 'F70_ADD', 'DF70_ADD',
#        'F70_ADD_TOT', 'DF70_ADD_TOT', 'ULIM_70', 'DESIGNATION_160', 'F160',
#        'DF160', 'F160_ADD', 'DF160_ADD', 'ULIM_160', 'DESIGNATION_250', 'F250',
#        'DF250', 'DESIGNATION_350', 'F350', 'DF350', 'FSC350', 'DFSC350',
#        'DESIGNATION_500', 'F500', 'DF500', 'FSC500', 'DFSC500',
#        'DESIGNATION_21', 'F21', 'DF21', 'F21_TOT', 'DF21_TOT',
#        'DESIGNATION_22', 'F22', 'DF22', 'F22_TOT', 'DF22_TOT',
#        'DESIGNATION_24', 'F24', 'DF24', 'F24_TOT', 'DF24_TOT',
#        'DESIGNATION_870', 'F870', 'DF870', 'DESIGNATION_1100', 'F1100',
#        'DF1100', 'DFWHM250', 'DIST', 'NEAR_DIST', 'FAR_DIST', 'DIST_FLAG',
#        'DIAM', 'M_LARS', 'FIT_TYPE', 'EVOL_FLAG', 'MASS', 'DMASS', 'TEMP',
#        'DTEMP', 'LAM_0_TK', 'L_BOL', 'LRATIO', 'T_BOL', 'SURF_DENS'],
#       dtype='object')

# %%
# Out:
#      ID           DESIGNATION      GLON      GLAT         ra        dec  \
# 0  4454  HIGALBM9.2545+1.0842  9.254488  1.084173  270.54295 -20.408795
# 1  4455  HIGALBM9.2569-0.2825  9.256889 -0.282502  271.81796 -21.076705
# 2  4456  HIGALBM9.2582-0.4725  9.258172 -0.472514  271.99662 -21.167985
#
#   DESIGNATION_70  F70  DF70  F70_TOT  ...  EVOL_FLAG   MASS  DMASS   TEMP  \
# 0              -  0.0   0.0      0.0  ...        1.0  -7.63  -1.86  10.84
# 1              -  0.0   0.0      0.0  ...        1.0 -30.79  -6.40  10.31
# 2              -  0.0   0.0      0.0  ...        1.0 -10.36  -2.69  12.32
#
#    DTEMP  LAM_0_TK L_BOL  LRATIO  T_BOL  SURF_DENS
# 0   0.48       0.0 -1.19    5.19  16.79      0.073
# 1   0.42      70.3 -3.38    4.31  15.70      0.551
# 2   0.66       0.0 -3.49    7.70  19.08      0.105
#
# [3 rows x 74 columns]

# %%
cat.head(3)
# Out:
#      ID           DESIGNATION      GLON      GLAT         ra        dec  \
# 0  4454  HIGALBM9.2545+1.0842  9.254488  1.084173  270.54295 -20.408795
# 1  4455  HIGALBM9.2569-0.2825  9.256889 -0.282502  271.81796 -21.076705
# 2  4456  HIGALBM9.2582-0.4725  9.258172 -0.472514  271.99662 -21.167985
#
#   DESIGNATION_70  F70  DF70  F70_TOT  ...  EVOL_FLAG   MASS  DMASS   TEMP  \
# 0              -  0.0   0.0      0.0  ...        1.0  -7.63  -1.86  10.84
# 1              -  0.0   0.0      0.0  ...        1.0 -30.79  -6.40  10.31
# 2              -  0.0   0.0      0.0  ...        1.0 -10.36  -2.69  12.32
#
#    DTEMP  LAM_0_TK L_BOL  LRATIO  T_BOL  SURF_DENS
# 0   0.48       0.0 -1.19    5.19  16.79      0.073
# 1   0.42      70.3 -3.38    4.31  15.70      0.551
# 2   0.66       0.0 -3.49    7.70  19.08      0.105
#
# [3 rows x 74 columns]

# %% [markdown]
# # Act 2 - KNN - Get Started
# #### 2.1 prepare your data by only have these columns:
# - cols= ['F70', 'F160', 'F250', 'F350', 'F500', 'F21', 'F22', 'F24', 'F870', 'F1100']
# - Also, for now let's not worry about where EVOL_FLAG equals to 0. Also, exclude them

# %%
cols = ['F70', 'F160', 'F250', 'F350', 'F500', 'F21', 'F22', 'F24', 'F870', 'F1100'] 
X = cat[cols][cat['EVOL_FLAG']>0]

# %%
Y = cat['EVOL_FLAG'][cat['EVOL_FLAG']>0]

# %%
X
# Out:
#          F70    F160    F250    F350    F500  F21    F22    F24  F870  F1100
# 0      0.000   0.000   4.852   3.755   1.703  0.0  0.000  0.000  0.00    0.0
# 1      0.000   3.454  11.413   6.738  10.814  0.0  0.000  0.000  0.00    0.0
# 2      0.000   0.000   9.697   6.108   2.948  0.0  0.000  0.000  0.00    0.0
# 3      0.000   1.229   8.061   4.141   5.217  0.0  0.000  0.000  0.00    0.0
# 4      0.000   0.000  30.386  10.795   5.831  0.0  0.000  0.000  0.00    0.0
# ...      ...     ...     ...     ...     ...  ...    ...    ...   ...    ...
# 1726   0.000   6.327  15.921   8.838   3.416  0.0  0.000  0.000  0.00    0.0
# 1728   0.494   1.732   2.816   2.499   2.009  0.0  0.000  0.003  0.15    0.0
# 1729   0.000   6.936   8.044   4.126   2.537  0.0  0.000  0.000  0.00    0.0
# 1730  17.853  27.037  38.971  21.206  10.956  0.0  1.763  1.604  0.86    0.0
# 1731   0.000   5.925  15.190  11.845   4.672  0.0  0.050  0.000  0.00    0.0
#
# [1640 rows x 10 columns]

# %% [markdown]
# #### 2.2 Perform your train_test_split! and print out X dataset!

# %%
X
# Out:
#          F70    F160    F250    F350    F500  F21    F22    F24  F870  F1100
# 0      0.000   0.000   4.852   3.755   1.703  0.0  0.000  0.000  0.00    0.0
# 1      0.000   3.454  11.413   6.738  10.814  0.0  0.000  0.000  0.00    0.0
# 2      0.000   0.000   9.697   6.108   2.948  0.0  0.000  0.000  0.00    0.0
# 3      0.000   1.229   8.061   4.141   5.217  0.0  0.000  0.000  0.00    0.0
# 4      0.000   0.000  30.386  10.795   5.831  0.0  0.000  0.000  0.00    0.0
# ...      ...     ...     ...     ...     ...  ...    ...    ...   ...    ...
# 1726   0.000   6.327  15.921   8.838   3.416  0.0  0.000  0.000  0.00    0.0
# 1728   0.494   1.732   2.816   2.499   2.009  0.0  0.000  0.003  0.15    0.0
# 1729   0.000   6.936   8.044   4.126   2.537  0.0  0.000  0.000  0.00    0.0
# 1730  17.853  27.037  38.971  21.206  10.956  0.0  1.763  1.604  0.86    0.0
# 1731   0.000   5.925  15.190  11.845   4.672  0.0  0.050  0.000  0.00    0.0
#
# [1640 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.33, random_state=42)
X
# Out:
#          F70    F160    F250    F350    F500  F21    F22    F24  F870  F1100
# 0      0.000   0.000   4.852   3.755   1.703  0.0  0.000  0.000  0.00    0.0
# 1      0.000   3.454  11.413   6.738  10.814  0.0  0.000  0.000  0.00    0.0
# 2      0.000   0.000   9.697   6.108   2.948  0.0  0.000  0.000  0.00    0.0
# 3      0.000   1.229   8.061   4.141   5.217  0.0  0.000  0.000  0.00    0.0
# 4      0.000   0.000  30.386  10.795   5.831  0.0  0.000  0.000  0.00    0.0
# ...      ...     ...     ...     ...     ...  ...    ...    ...   ...    ...
# 1726   0.000   6.327  15.921   8.838   3.416  0.0  0.000  0.000  0.00    0.0
# 1728   0.494   1.732   2.816   2.499   2.009  0.0  0.000  0.003  0.15    0.0
# 1729   0.000   6.936   8.044   4.126   2.537  0.0  0.000  0.000  0.00    0.0
# 1730  17.853  27.037  38.971  21.206  10.956  0.0  1.763  1.604  0.86    0.0
# 1731   0.000   5.925  15.190  11.845   4.672  0.0  0.050  0.000  0.00    0.0
#
# [1640 rows x 10 columns]

# %% [markdown]
# #### 2.3 Scaling
# - Perform the scaling!
#
# **Do we fit the scaling model on the X_test or we only tranform the model from training set to the test? Why?**
#
# - Print out your scaled X_train (Note: you may need to convert it to a dataframe)
# - Print out your scaled X_test (Note: you may need to convert it to a dataframe)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scal = StandardScaler()
scld_X_train = scal.fit_transform(X_train)
scld_X_test = scal.transform(X_test)

# %%
scaled_X_train = pd.DataFrame(scld_X_train, columns=cols)
scaled_X_test = pd.DataFrame(scld_X_test, columns=cols)

# %%
scaled_X_train
# Out:
#           F70      F160      F250      F350      F500      F21       F22  \
# 0    -0.17445 -0.264367 -0.280474 -0.298848 -0.261318 -0.05591 -0.112709
# 1    -0.17445 -0.264367 -0.003510  0.148299  0.130428 -0.05591 -0.112709
# 2    -0.17445 -0.225383 -0.323906 -0.310588 -0.305237 -0.05591 -0.112709
# 3    -0.17445 -0.229354 -0.344466 -0.348813 -0.364255 -0.05591 -0.112709
# 4    -0.17445 -0.264367 -0.321570 -0.122806  0.010715 -0.05591 -0.112709
# ...       ...       ...       ...       ...       ...      ...       ...
# 1093 -0.17445 -0.237680 -0.359369 -0.274867 -0.117688 -0.05591 -0.112709
# 1094 -0.17445 -0.149379 -0.157174  0.106427  0.113953 -0.05591 -0.112709
# 1095 -0.17445 -0.264367 -0.359795 -0.353041 -0.355566 -0.05591 -0.112709
# 1096 -0.17445 -0.264367 -0.304374 -0.292417 -0.326444 -0.05591 -0.112709
# 1097 -0.14003 -0.176969 -0.300094 -0.283581 -0.325971 -0.05591 -0.112709
#
#            F24      F870  F1100
# 0     0.107909 -0.288356    0.0
# 1     0.107909 -0.288356    0.0
# 2     0.107909 -0.288356    0.0
# 3     0.107909 -0.288356    0.0
# 4     0.107909 -0.110035    0.0
# ...        ...       ...    ...
# 1093  0.107909 -0.288356    0.0
# 1094  0.107909  0.328691    0.0
# 1095  0.107909 -0.288356    0.0
# 1096  0.107909 -0.288356    0.0
# 1097  0.108085 -0.288356    0.0
#
# [1098 rows x 10 columns]

# %%
# Out:
#           F70      F160      F250      F350      F500      F21       F22  \
# 0    -0.17445 -0.264367 -0.280474 -0.298848 -0.261318 -0.05591 -0.112709
# 1    -0.17445 -0.264367 -0.003510  0.148299  0.130428 -0.05591 -0.112709
# 2    -0.17445 -0.225383 -0.323906 -0.310588 -0.305237 -0.05591 -0.112709
# 3    -0.17445 -0.229354 -0.344466 -0.348813 -0.364255 -0.05591 -0.112709
# 4    -0.17445 -0.264367 -0.321570 -0.122806  0.010715 -0.05591 -0.112709
# ...       ...       ...       ...       ...       ...      ...       ...
# 1093 -0.17445 -0.237680 -0.359369 -0.274867 -0.117688 -0.05591 -0.112709
# 1094 -0.17445 -0.149379 -0.157174  0.106427  0.113953 -0.05591 -0.112709
# 1095 -0.17445 -0.264367 -0.359795 -0.353041 -0.355566 -0.05591 -0.112709
# 1096 -0.17445 -0.264367 -0.304374 -0.292417 -0.326444 -0.05591 -0.112709
# 1097 -0.14003 -0.176969 -0.300094 -0.283581 -0.325971 -0.05591 -0.112709
#
#            F24      F870  F1100
# 0     0.107909 -0.288356    0.0
# 1     0.107909 -0.288356    0.0
# 2     0.107909 -0.288356    0.0
# 3     0.107909 -0.288356    0.0
# 4     0.107909 -0.110035    0.0
# ...        ...       ...    ...
# 1093  0.107909 -0.288356    0.0
# 1094  0.107909  0.328691    0.0
# 1095  0.107909 -0.288356    0.0
# 1096  0.107909 -0.288356    0.0
# 1097  0.108085 -0.288356    0.0
#
# [1098 rows x 10 columns]

# %%
scaled_X_test
# Out:
#           F70      F160      F250      F350      F500       F21       F22  \
# 0   -0.174450 -0.226207 -0.317104 -0.322128 -0.353329 -0.055910 -0.112709
# 1   -0.174450 -0.264367 -0.287429 -0.246217 -0.301452 -0.055910 -0.112709
# 2    0.688900  0.181843  0.498054  0.743199 -0.431876  0.145653  0.919954
# 3   -0.174450 -0.161342 -0.162567 -0.055450 -0.139454 -0.055910 -0.112709
# 4   -0.170394 -0.253272 -0.339530 -0.324091 -0.309797 -0.055910 -0.112709
# ..        ...       ...       ...       ...       ...       ...       ...
# 537 -0.174450 -0.236593 -0.326647 -0.310468 -0.322745 -0.055910 -0.112709
# 538 -0.098559 -0.107442 -0.226079 -0.229228 -0.132012 -0.055910 -0.112709
# 539  0.031483 -0.022121 -0.180528 -0.221796 -0.202730 -0.055910  0.083015
# 540 -0.146449 -0.215313 -0.194601 -0.231532 -0.431876 -0.055910 -0.095662
# 541  1.032121  0.685741  0.331954  0.132252 -0.058842  0.122072  0.751758
#
#           F24      F870  F1100
# 0    0.107909 -0.288356    0.0
# 1    0.107909 -0.288356    0.0
# 2    0.152174  0.299820    0.0
# 3    0.107909  0.198488    0.0
# 4    0.107909 -0.288356    0.0
# ..        ...       ...    ...
# 537  0.107909 -0.288356    0.0
# 538  0.109334 -0.288356    0.0
# 539  0.125184 -0.288356    0.0
# 540  0.108538 -0.288356    0.0
# 541  0.148038  0.260759    0.0
#
# [542 rows x 10 columns]

# %%
# Out:
#           F70      F160      F250      F350      F500       F21       F22  \
# 0   -0.174450 -0.226207 -0.317104 -0.322128 -0.353329 -0.055910 -0.112709
# 1   -0.174450 -0.264367 -0.287429 -0.246217 -0.301452 -0.055910 -0.112709
# 2    0.688900  0.181843  0.498054  0.743199 -0.431876  0.145653  0.919954
# 3   -0.174450 -0.161342 -0.162567 -0.055450 -0.139454 -0.055910 -0.112709
# 4   -0.170394 -0.253272 -0.339530 -0.324091 -0.309797 -0.055910 -0.112709
# ..        ...       ...       ...       ...       ...       ...       ...
# 537 -0.174450 -0.236593 -0.326647 -0.310468 -0.322745 -0.055910 -0.112709
# 538 -0.098559 -0.107442 -0.226079 -0.229228 -0.132012 -0.055910 -0.112709
# 539  0.031483 -0.022121 -0.180528 -0.221796 -0.202730 -0.055910  0.083015
# 540 -0.146449 -0.215313 -0.194601 -0.231532 -0.431876 -0.055910 -0.095662
# 541  1.032121  0.685741  0.331954  0.132252 -0.058842  0.122072  0.751758
#
#           F24      F870  F1100
# 0    0.107909 -0.288356    0.0
# 1    0.107909 -0.288356    0.0
# 2    0.152174  0.299820    0.0
# 3    0.107909  0.198488    0.0
# 4    0.107909 -0.288356    0.0
# ..        ...       ...    ...
# 537  0.107909 -0.288356    0.0
# 538  0.109334 -0.288356    0.0
# 539  0.125184 -0.288356    0.0
# 540  0.108538 -0.288356    0.0
# 541  0.148038  0.260759    0.0
#
# [542 rows x 10 columns]

# %% [markdown]
# # Act 3 - Perform KNN
# #### 3.1 Do it for k=2

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KNN = KNeighborsClassifier(n_neighbors = 2)

# %%
KNN.fit(scld_X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_pred = KNN.predict(scld_X_test)

# %% [markdown]
# #### 3.2 Think about how we can determine the error? Maybe you would have a better way than how I would approach! So, feel free to educate me!
# - Is MSE a good aproach? Let's say your class is 0 and predict 2! How is this different from predicting 1 for class 0? Our model was incorrect in both cases! So, maybe MSE is not the best way!
# - What if for now we simply count the number of times when y_test and our prediction do not match?
# - Maybe not a bad idea to take its mean!

# %%
k=0
for n1, n2 in zip(y_test,y_pred):
    if n1 != n2:
        k+=1
k/len(y_test)
# Out:
# 0.21033210332103322

# %%
# Out:
# 0.21033210332103322

# %% [markdown]
# # Act 4 - Perform KNN for i in range(1,40)
# #### 4.1 Perform KNN for i in range(1,40)

# %%
error_1 = []
k = range(1,40)
for i in k:
    KNN1 = KNeighborsClassifier(n_neighbors = i)
    KNN1.fit(scld_X_train, y_train)
    n = 0
    for n1, n2, in zip(y_test,KNN1.predict(scld_X_test)):
        if n1 != n2:
            n+=1
    error_1.append(n/len(y_test))

# %% [markdown]
# #### 4.2 Create a plot of Error vs K Number. Make your plot as close as possible to the one below!

# %%
plt.figure(figsize=(10,6))
plt.xlabel('K value')
plt.ylabel('Error')
plt.title('Error vs K value')
sns.lineplot(x=k, y= error_1, markersize = 10, markerfacecolor= 'blue',marker='o',linestyle='dashed', 
             linewidth = 2, color='red')
# Out:
# <AxesSubplot:title={'center':'Error vs K value'}, xlabel='K value', ylabel='Error'>

# %% [markdown]
# #### 4.3 Redo it for the minimum cvalue and print out the classification report and confusion matrix

# %%
KNN2 = KNeighborsClassifier(n_neighbors = 5)
KNN2.fit(scld_X_train, y_train)
pred_2 = KNN2.predict(scld_X_test)

from sklearn.metrics import classification_report,confusion_matrix

print(confusion_matrix(y_test, pred_2))
print(classification_report(y_test, pred_2))
# Out:
# [[246  27]
#  [ 64 205]]
#               precision    recall  f1-score   support
#
#          1.0       0.79      0.90      0.84       273
#          2.0       0.88      0.76      0.82       269
#
#     accuracy                           0.83       542
#    macro avg       0.84      0.83      0.83       542
# weighted avg       0.84      0.83      0.83       542

# %%
# Out:
# [[246  27]
#  [ 64 205]]
#               precision    recall  f1-score   support
#
#          1.0       0.79      0.90      0.84       273
#          2.0       0.88      0.76      0.82       269
#
#     accuracy                           0.83       542
#    macro avg       0.84      0.83      0.83       542
# weighted avg       0.84      0.83      0.83       542

# %% [markdown]
# # Act 5 - What if we include class zeros?
# #### 5.1 Copy and paste your work from above! Try to have most of them in one cell!

# %%
cols = ['F70', 'F160', 'F250', 'F350', 'F500', 'F21', 'F22', 'F24', 'F870', 'F1100'] 
X = cat[cols][cat['EVOL_FLAG']>=0]
Y = cat['EVOL_FLAG'][cat['EVOL_FLAG']>=0]
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.33, random_state=42)
scal = StandardScaler()
scld_X_train = scal.fit_transform(X_train)
scld_X_test = scal.transform(X_test)
scaled_X_train = pd.DataFrame(scld_X_train, columns=cols)
scaled_X_test = pd.DataFrame(scld_X_test, columns=cols)

error_2 = []
for i in k:
    KNN3 = KNeighborsClassifier(n_neighbors = i)
    KNN3.fit(scld_X_train, y_train)
    n = 0
    for n1, n2, in zip(y_test,KNN3.predict(scld_X_test)):
        if n1 != n2:
            n+=1
    error_2.append(n/len(y_test))

plt.figure(figsize=(10,6))
plt.xlabel('K value')
plt.ylabel('Error')
plt.title('Error vs K value')
sns.lineplot(x=k, y= error_2, markersize = 10, markerfacecolor= 'blue',marker='o',linestyle='dashed', 
             linewidth = 2, color='red')
# Out:
# <AxesSubplot:title={'center':'Error vs K value'}, xlabel='K value', ylabel='Error'>

# %% [markdown]
# #### 5.2 For the minimum value run it again and print the classification report and confusion matrix

# %%
np.argmin(error_2)
# Out:
# 6

# %%
# since k starts at 1 the minimum is at k = 7
KNN4 = KNeighborsClassifier(n_neighbors = 7)
KNN4.fit(scld_X_train, y_train)
pred_4 = KNN4.predict(scld_X_test)

from sklearn.metrics import classification_report,confusion_matrix

print(confusion_matrix(y_test, pred_4))
print(classification_report(y_test, pred_4))
# Out:
# [[ 12  12   1]
#  [ 13 242  30]
#  [  1  58 203]]
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.48      0.47        25
#          1.0       0.78      0.85      0.81       285
#          2.0       0.87      0.77      0.82       262
#
#     accuracy                           0.80       572
#    macro avg       0.70      0.70      0.70       572
# weighted avg       0.80      0.80      0.80       572

# %%
# Out:
# [[ 13  10   2]
#  [ 14 240  31]
#  [  3  62 197]]
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.52      0.47        25
#          1.0       0.77      0.84      0.80       285
#          2.0       0.86      0.75      0.80       262
#
#     accuracy                           0.79       572
#    macro avg       0.69      0.70      0.69       572
# weighted avg       0.79      0.79      0.79       572

# %% [markdown]
# # $\Large Well, \ not \ the \ best \ of \ our \ work, \ I \ guess!$
#
# # Act 6 - Maybe we didn't spend enough time understanding the data! Let's do some more plotting!

# %% [markdown]
# #### 6.1 Can you create the following barplot of the mean value?
# Hint: you may need to use order option via sns.barplot

# %%
X.columns
# Out:
# Index(['F70', 'F160', 'F250', 'F350', 'F500', 'F21', 'F22', 'F24', 'F870',
#        'F1100'],
#       dtype='object')

# %%
# Out:
# Index(['F70', 'F160', 'F250', 'F350', 'F500', 'F21', 'F22', 'F24', 'F870',
#        'F1100'],
#       dtype='object')

# %%
sns.barplot(data=X, order=['F21', 'F22', 'F24', 'F70', 'F160', 'F250', 'F350', 'F500', 'F870','F1100'], ci=None)
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 6.2 How does the box plot of the non-scaled X_train and scaled version of X_train look?

# %%
sns.boxplot(data=X_train)
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=scld_X_train)
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 6.3 What if we create two dataframes:
# - 1. X + the Evolutionary Flag --> I called it 'df'
# - 2. scaled X_train + the Evolutionary Flag --> I called it 'df_scal'

# %%
df = cat[['F70', 'F160', 'F250', 'F350', 'F500', 'F21', 'F22', 'F24', 'F870', 'F1100','EVOL_FLAG']]

# %%
df_scal = pd.DataFrame(scld_X_train)
df_scal.columns = ['F70', 'F160', 'F250', 'F350', 'F500', 'F21', 'F22', 'F24', 'F870', 'F1100']
df_scal['EVOL_FLAG'] = cat['EVOL_FLAG']

# %%
df_scal
# Out:
#            F70      F160      F250      F350      F500       F21       F22  \
# 0    -0.183652 -0.336886 -0.314141 -0.258221 -0.285505 -0.062407 -0.091254
# 1    -0.183652 -0.247361 -0.268883 -0.312953 -0.317402 -0.062407 -0.092647
# 2    -0.114975 -0.080542  0.011775 -0.188082 -0.106097 -0.062407 -0.092647
# 3    -0.183652 -0.245059 -0.286239 -0.333577 -0.159329 -0.062407 -0.092647
# 4    -0.183652 -0.225908 -0.216068 -0.199370  0.263696 -0.062407 -0.092647
# ...        ...       ...       ...       ...       ...       ...       ...
# 1155 -0.030161  0.109861  0.027335 -0.057004 -0.027082 -0.062407 -0.092647
# 1156 -0.183652 -0.336886 -0.326193 -0.217748 -0.216345 -0.062407 -0.092647
# 1157 -0.183652 -0.228983 -0.272125 -0.349093 -0.357326 -0.062407 -0.092647
# 1158 -0.183652  0.174379 -0.080573  0.067893  0.161558 -0.062407 -0.092647
# 1159 -0.183652 -0.305918 -0.364244 -0.414899 -0.369428 -0.062407 -0.092647
#
#            F24      F870  F1100  EVOL_FLAG
# 0     0.117131 -0.296554    0.0        1.0
# 1     0.117131 -0.296554    0.0        1.0
# 2     0.117131 -0.296554    0.0        1.0
# 3     0.117131 -0.296554    0.0        1.0
# 4     0.117131 -0.296554    0.0        1.0
# ...        ...       ...    ...        ...
# 1155  0.117148 -0.040510    0.0        2.0
# 1156  0.117131 -0.296554    0.0        2.0
# 1157  0.117131 -0.296554    0.0        2.0
# 1158 -8.455662 -0.034792    0.0        2.0
# 1159  0.117131 -0.296554    0.0        2.0
#
# [1160 rows x 11 columns]

# %%
df['EVOL_FLAG'] = cat['EVOL_FLAG']
# Out:
# <ipython-input-145-efde4e29ac4e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EVOL_FLAG'] = cat['EVOL_FLAG']

# %%
# Out:
# <ipython-input-289-72508f71a8d7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['EVOL_FLAG']=y

# %% [markdown]
# #### 6.4 Create the folowing plot ['F70', 'F160', 'F250', 'F350', 'F500']

# %%
df.columns
# Out:
# Index(['F70', 'F160', 'F250', 'F350', 'F500', 'F21', 'F22', 'F24', 'F870',
#        'F1100', 'EVOL_FLAG'],
#       dtype='object')

# %%
# Out:
# Index(['F70', 'F160', 'F250', 'F350', 'F500', 'F21', 'F22', 'F24', 'F870',
#        'F1100', 'EVOL_FLAG'],
#       dtype='object')

# %%
df['F70']
# Out:
# 0        0.000
# 1        0.000
# 2        0.000
# 3        0.000
# 4        0.000
#          ...
# 1727     0.000
# 1728     0.494
# 1729     0.000
# 1730    17.853
# 1731     0.000
# Name: F70, Length: 1732, dtype: float64

# %%
sns.pairplot(df_scal[['F70', 'F160', 'F250', 'F350', 'F500', 'EVOL_FLAG']], hue= 'EVOL_FLAG')

# %% [markdown]
# #### 6.5 Let's look at it closer! Create the following plots.

# %%
plt.xlim(-1,5)
plt.ylim(-1,5)
sns.scatterplot(data = df_scal[(df_scal['F70']>-1) & (df_scal['F70']<5) & (df_scal['F160']>-1)&(df_scal['F160']<5)], 
                x='F70', y='F160', hue='EVOL_FLAG', palette='bright')
# Out:
# <AxesSubplot:xlabel='F70', ylabel='F160'>

# %%
# Out:
# (-1.0, 5.0)

# %%
# Out:
# (-1.0, 5.0)

# %% [markdown]
# # Act 7 - What if we include the rest of the columns?
#
# i.e. ['F70', 'F160', 'F250', 'F350', 'F500','F870', 'F1100', 'DIST', 'DIAM', 'EVOL_FLAG', 'MASS', 'TEMP', 'L_BOL', 'T_BOL', 'SURF_DENS']
# #### Seems like maybe we should have got ridden off the F20,F21, F24
#
# #### Also, all those negative values are annoying! So, get rid of all MASS and L_BOL with the negative values

# %%
df2 = cat[['F70', 'F160', 'F250', 'F350', 'F500','F870', 'F1100'
           , 'DIST', 'DIAM', 'EVOL_FLAG', 'MASS', 'TEMP', 'L_BOL'
           , 'T_BOL', 'SURF_DENS']][(cat['MASS'] >=0) & (cat['L_BOL']>=0 )]

# %% [markdown]
# #### 7.2 How many EVOL_FLAG == 0 is left?

# %%
df2[df2['EVOL_FLAG']==0].count()
# Out:
# F70          27
# F160         27
# F250         27
# F350         27
# F500         27
# F870         27
# F1100        27
# DIST         27
# DIAM         27
# EVOL_FLAG    27
# MASS         27
# TEMP         27
# L_BOL        27
# T_BOL        27
# SURF_DENS    27
# dtype: int64

# %%
# Out:
# F70          27
# F160         27
# F250         27
# F350         27
# F500         27
# F870         27
# F1100        27
# DIST         27
# DIAM         27
# EVOL_FLAG    27
# MASS         27
# TEMP         27
# L_BOL        27
# T_BOL        27
# SURF_DENS    27
# dtype: int64

# %% [markdown]
# #### 7.3 I dont' think we need them in our data set!

# %%
cols2 = ['F70', 'F160', 'F250', 'F350', 'F500','F870', 'F1100', 'DIST', 'DIAM', 'MASS', 'TEMP', 'L_BOL', 'T_BOL', 'SURF_DENS']
X = cat[cols2][(cat['EVOL_FLAG']>0) & (cat['MASS'] >=0) & (cat['L_BOL']>=0 )]
Y = cat['EVOL_FLAG'][(cat['EVOL_FLAG']>0) & (cat['MASS'] >=0) & (cat['L_BOL']>=0 )]

# %% [markdown]
# #### 7.4 Perform KNN for K=1-40 on your new dataset! Note that this time we are including all the columns as above!

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.33, random_state=42)
scal = StandardScaler()
scld_X_train = scal.fit_transform(X_train)
scld_X_test = scal.transform(X_test)
scaled_X_train = pd.DataFrame(scld_X_train, columns=cols2)
scaled_X_test = pd.DataFrame(scld_X_test, columns=cols2)

error_5 = []
for i in k:
    KNN5 = KNeighborsClassifier(n_neighbors = i)
    KNN5.fit(scld_X_train, y_train)
    n = 0
    for n1, n2, in zip(y_test,KNN5.predict(scld_X_test)):
        if n1 != n2:
            n+=1
    error_5.append(n/len(y_test))

plt.figure(figsize=(10,6))
plt.xlabel('K value')
plt.ylabel('Error')
plt.title('Error vs K value')
sns.lineplot(x=k, y= error_5, markersize = 10, markerfacecolor= 'blue',marker='o',linestyle='dashed', 
             linewidth = 2, color='red')
# Out:
# <AxesSubplot:title={'center':'Error vs K value'}, xlabel='K value', ylabel='Error'>

# %% [markdown]
# #### 7.5 Look at the classification report and confusion matrix!

# %%
KNN6 = KNeighborsClassifier(n_neighbors = 11)
KNN6.fit(scld_X_train, y_train)
pred_6 = KNN6.predict(scld_X_test)
print(confusion_matrix(y_test, pred_6))
print(classification_report(y_test, pred_6))
# Out:
# [[ 77   5]
#  [ 15 107]]
#               precision    recall  f1-score   support
#
#          1.0       0.84      0.94      0.89        82
#          2.0       0.96      0.88      0.91       122
#
#     accuracy                           0.90       204
#    macro avg       0.90      0.91      0.90       204
# weighted avg       0.91      0.90      0.90       204

# %%
# Out:
# [[ 77   5]
#  [ 15 107]]
#               precision    recall  f1-score   support
#
#          1.0       0.84      0.94      0.89        82
#          2.0       0.96      0.88      0.91       122
#
#     accuracy                           0.90       204
#    macro avg       0.90      0.91      0.90       204
# weighted avg       0.91      0.90      0.90       204

# %% [markdown]
# #### How do you compare it to your work in Act 4.3?

# %% [markdown]
# ![image.png](attachment:image.png)
